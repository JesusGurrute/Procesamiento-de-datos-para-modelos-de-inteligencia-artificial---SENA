# %% [markdown]
# TÉCNICO EN PROCESAMIENTO DE DATOS PARA MODELOS DE INTELGENCIA ARTIFICIAL - SENA
# CÓDIGO_ 3175949
# APRENDIZ: JESÚS ALIRIO GURRUTE CAMPO

# %% [markdown]
# ##📝**TAREA**
#
# Utiliza la plataforma [Programiz](https://www.programiz.com/python-programming/online-compiler/) para escribir las siguientes instrucciones en Python.
#
# var1 = 15
#
# **Resultado:** Ejecuta el código en [Programiz](https://www.programiz.com/python-programming/online-compiler/) y anota el resultado en la siguiente tabla.
#
# ![Screenshot 2025-06-21 072729.png](data:image/png;base64,...)

# %% [markdown]
# ##**SOLUCIÓN**

# %% [markdown]
# ![Screenshot 2025-06-21 093250.png](data:image/png;base64,...)

# %% [markdown]
# ##1.

# %%
var1 = 15
vari = var1 - vari
print(vari)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-24-1099504142.py in <cell line: 0>()
#       1 var1 = 15
# ----> 2 vari = var1 - vari
#       3 print(vari)
#
# NameError: name 'vari' is not defined

# %% [markdown]
# ![Screenshot 2025-06-21 075322.png](data:image/png;base64,...)

# %% [markdown]
# ##2.

# %%
var1 = 15
vari = var1 + 30 / var1

print(vari)
# Out:
# 17.0

# %% [markdown]
# ![Screenshot 2025-06-21 080700.png](data:image/png;base64,...)

# %% [markdown]
# ##3.

# %%
var1 =  15
vari = vari + 3
print(vari)

# %% [markdown]
# ![Screenshot 2025-06-21 083114.png](data:image/png;base64,...)

# %% [markdown]
# ##4.

# %%
var1 = 15
vari = var1 + 3 / 2
print(vari)
# Out:
# 16.5

# %% [markdown]
# ![Screenshot 2025-06-21 083644.png](data:image/png;base64,...)

# %% [markdown]
# ##5

# %%
var1 = 15
vari = var1 + 3 * 2
print(vari)
# Out:
# 21

# %% [markdown]
# ![Screenshot 2025-06-21 092034.png](data:image/png;base64,...)

# %% [markdown]
# ##6.

# %%
var1 = 15
vari = (var1 + 3) * 2
print(vari)
# Out:
# 36

# %% [markdown]
# ![Screenshot 2025-06-21 092815.png](data:image/png;base64,...)

# %% [markdown]
# Considerando que 'aux' y 'aux1' son variables enteras.
# ##📝**TAREA**
#
#  Utiliza la plataforma [Programiz](https://www.programiz.com/python-programming/online-compiler/) para escribir las siguientes instrucciones en Python.
#   aux1=15
# **Resultado:** Ejecuta el código en [Programiz](https://www.programiz.com/python-programming/online-compiler/) y anota los resultados en la siguiente tabla.
#
# ![Screenshot 2025-06-22 192044.png](data:image/png;base64,...)

# %% [markdown]
# ##**SOLUCIÓN**

# %% [markdown]
# ![Screenshot 2025-06-22 194535.png](data:image/png;base64,...)

# %%
aux1 = 15
aux = None
print(aux)
type(aux)
# Out:
# None
# NoneType

# %% [markdown]
# ![Screenshot 2025-06-22 193103.png](data:image/png;base64,...)

# %%
aux1 = 15
aux = 90 / aux;
print(aux)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-5-3162165024.py in <cell line: 0>()
#       1 aux1 = 15
# ----> 2 aux = 90 / aux;
#       3 print(aux)
#
# NameError: name 'aux' is not defined

# %% [markdown]
# ![Screenshot 2025-06-22 193457.png](data:image/png;base64,...)

# %%
aux1 = 15
aux = 90 / aux1
print(aux)
# Out:
# 6.0

# %% [markdown]
# ![Screenshot 2025-06-22 193920.png](data:image/png;base64,...)

# %%
aux1 = 15
aux = 0
print(aux)
# Out:
# 0

# %% [markdown]
# ![Screenshot 2025-06-22 194229.png](data:image/png;base64,...)

# %%
aux1 = 15
aux = aux1 /aux
print(aux)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-11-706791711.py in <cell line: 0>()
#       1 aux1 = 15
# ----> 2 aux = aux1 /aux
#       3 print(aux)
#
# NameError: name 'aux' is not defined

# %% [markdown]
# ![Screenshot 2025-06-22 194443.png](data:image/png;base64,...)

# %% [markdown]
# ##📝**Tarea**
# Teniendo en cuenta que las variables
# i = 7 (entero)
# f = 5.5 (real)
# c = ‘w’ (caracter) (ASCII 119).
#
# Analiza la expresión completa de la siguiente tabla con su valor lógico y su valor binario (0 o 1).
#
# ![Screenshot 2025-06-22 203105.png](data:image/png;base64,...)

# %% [markdown]
# ##**SOLUCIÓN**

# %% [markdown]
# ![Screenshot 2025-06-23 082222.png](data:image/png;base64,...)

# %%
i = 7
f = 5.5
c = 'w'
(i >= 6) and (c == "w")
# Out:
# True

# %% [markdown]
# ![Screenshot 2025-06-22 203415.png](data:image/png;base64,...)

# %%
i = 7
f = 5.5
c = 'w'
(i >= 6) or (c == 119)
# Out:
# True

# %% [markdown]
# ![Screenshot 2025-06-22 203754.png](data:image/png;base64,...)

# %%
i = 7
f = 5.5
c = 'w'
(f < 11) and (i > 100)
# Out:
# False

# %% [markdown]
# ![Screenshot 2025-06-22 204121.png](data:image/png;base64,...)

# %%
i = 7
f = 5.5
c = 'w'
(c != "p") or ((i+f) <= 10)
# Out:
# True

# %% [markdown]
# ![Screenshot 2025-06-22 205136.png](data:image/png;base64,...)

# %%
i = 7
f = 5.5
c = 'w'
(i >= 6) or (c == 65)
# Out:
# True

# %% [markdown]
# ![Screenshot 2025-06-22 205416.png](data:image/png;base64,...)

# %%
i = 7
f = 5.5
c = 'w'

(c != "p") or ((i+f) >= 10)and (c == "W")
# Out:
# True

# %% [markdown]
# ![Screenshot 2025-06-22 205719.png](data:image/png;base64,...)

# %%
i = 7
f = 5.5
c = 'w'

(f < 11)  or  (i > 100) or (f==5.1)
# Out:
# True

# %% [markdown]
# ![Screenshot 2025-06-22 210004.png](data:image/png;base64,...)

# %%
i = 7
f = 5.5
c = 'w'

not((i >= 6) and (c == "w"))
# Out:
# False

# %% [markdown]
# ![Screenshot 2025-06-22 210347.png](data:image/png;base64,...)

# %% [markdown]
# ##📝**TAREA**
#
# En el cuadro a continuación, se presentan varias operaciones que almacenará un valor en una variable. En la columna titulada "Procedimiento Manual", escribe el resultado que obtienes al realizar la operación manualmente. Luego, utiliza el aplicativo Programiz para ejecutar las instrucciones en Python y anota el resultado en la columna "Programiz".
#
# ![Screenshot 2025-06-22 233923.png](data:image/png;base64,...)

# %% [markdown]
# ##**SOLUCIÓN**

# %% [markdown]
# ![Screenshot 2025-06-23 081826.png](data:image/png;base64,...)

# %%
operacion = 6/2*(2+1)
print(operacion)
# Out:
# 9.0

# %% [markdown]
# ![Screenshot 2025-06-22 234233.png](data:image/png;base64,...)

# %%
saldo = 45 + 18 / 9
print(saldo)
# Out:
# 47.0

# %% [markdown]
# ![Screenshot 2025-06-22 234655.png](data:image/png;base64,...)

# %%
saldo = (45 + 18) / 9
print(saldo)
# Out:
# 7.0

# %% [markdown]
# ![Screenshot 2025-06-22 234746.png](data:image/png;base64,...)

# %%
Operaciones2= 4+5*30/3-10
print(Operaciones2)
# Out:
# 44.0

# %% [markdown]
# ![Screenshot 2025-06-22 234950.png](data:image/png;base64,...)

# %%
aux = (15 - (8 - 5 ))* (5 + (6 - 4 )) - 3 + (8 - 6 )
print(aux)
# Out:
# 83

# %% [markdown]
# ![Screenshot 2025-06-22 235946.png](data:image/png;base64,...)

# %%
Saldo_3 = (100 + 45 / 5 * 2) - 1
print(Saldo_3)
# Out:
# 117.0

# %% [markdown]
# ![Screenshot 2025-06-23 000412.png](data:image/png;base64,...)

# %%
div = 34 / 11
print(div)
# Out:
# 3.090909090909091

# %% [markdown]
# ![Screenshot 2025-06-23 001323.png](data:image/png;base64,...)

# %%
div_2 = 34 //11
print(div_2)
# Out:
# 3

# %% [markdown]
# ![Screenshot 2025-06-23 001455.png](data:image/png;base64,...)

# %%
par_no_par = 23 % 2
print(par_no_par)
# Out:
# 1

# %% [markdown]
# ![Screenshot 2025-06-23 075909.png](data:image/png;base64,...)

# %%
a = (42 + 20) / 4 - 2 * (9 / 3) - 2 * (18 + 3 * (13 - 9) - 5)
print(a)
# Out:
# -40.5

# %% [markdown]
# ![Screenshot 2025-06-23 080401.png](data:image/png;base64,...)

# %%
b = (25* ((7 + 5* 2) + 3 * (3 * 3) - ( 20 / 5 ) ) ) * ( 9 - 2)
print(b)
# Out:
# 7000.0

# %% [markdown]
# ![Screenshot 2025-06-23 081113.png](data:image/png;base64,...)

# %%
C = 3 * ( -3 + (- 3)) - 14 / (- 7)
print(C)
# Out:
# -16.0

# %% [markdown]
# ![Screenshot 2025-06-23 081422.png](data:image/png;base64,...)

# %% [markdown]
# ##📝**TAREA**
# Soluciones ejercicios utilizando Pseudocódigo en Js o Python.

# %% [markdown]
# **1.** Codifique un algoritmo que solicite el nombre y devuelve como salida el mensaje: Hola nombre ingresado. Por ejemplo, si el usuario digita 'Ramón’, el mensaje desplegado será: ‘Hola Ramón’.

# %%
nombre = input("Ingrese un nombre: ")
print("Hola", nombre)
# Out:
# Ingrese un nombre: Ramón
# Hola Ramón

# %% [markdown]
# **2.** Realice un algoritmo que solicite dos números enteros, realice su suma y muestre el resultado.

# %%
num1 = int(input("Ingrese el primer número: "))
num2 = int(input("Ingrese el segundo número: "))
suma = num1 + num2
print("La suma de", num1, "y", num2, "es:", suma)
# Out:
# Ingrese el primer número: 4
# Ingrese el segundo número: -3
# La suma de 4 y -3 es: 1

# %% [markdown]
# **3.** Realizar un algoritmo que calcule el perímetro y el área de un rectángulo dadas la base y la altura del mismo.

# %%
largo = int(input("Ingrese el largo del rectángulo: "))
ancho = int(input("Ingrese el ancho del rectángulo: "))
perimetro = 2 * (largo + ancho)
area = largo * ancho
print("El perímetro del rectángulo es:", perimetro)
print("El área del rectángulo es:", area)
# Out:
# Ingrese el largo del rectángulo: 4
# Ingrese el ancho del rectángulo: 8
# El perímetro del rectángulo es: 24
# El área del rectángulo es: 32

# %% [markdown]
# **4.** Desarrolle un algoritmo que permita leer dos valores distintos, determinar cuál de los dos valores es el mayor y escribirlo.

# %%
num1 = int(input("Ingrese el primer número: "))
num2 = int(input("Ingrese el segundo número: "))
if (num1 != num2):
  if(num1 < num2):
    print(f"{num1} es menor que {num2}")
  else:
      print(f"{num2} es menor que {num1}")
else:
    print(f"{num1} es igual que {num2}")
# Out:
# Ingrese el primer número: 5
# Ingrese el segundo número: -1
# -1 es menor que 5

# %% [markdown]
# **5.** Desarrolle un algoritmo que permita leer tres valores y almacenarlos en las variables A, B y C respectivamente. El algoritmo debe imprimir cual es el mayor y cuál es el menor. Recuerde constatar que los tres valores introducidos por el teclado sean valores distintos. Presente un mensaje de alerta en caso de que se detecte la introducción de valores iguales.

# %%
a = int(input("Ingrese el valor de A: "))
b = int(input("Ingrese el valor de B: "))
c = int(input("Ingrese el valor de C: "))

if (a == b ==c):
    print("Los datos ingresados son iguales")
else:
    print(f"{max(a,b,c)} es mayor")
    print(f"{min(a,b,c)} es menor")
# Out:
# Ingrese primer valor: -3
# Ingrese primer valor: -4
# Ingrese primer valor: -3
# -3 es mayor
# -4 es menor

# %% [markdown]
# **6.** Dado un número imprimir un mensaje que diga si es par o impar.

# %%
num1 = int(input("Ingrese un número: "))
if (num1%2 == 0):
    print("{} es par".format(num1))
else:
    print("{} es impar".format(num1))
# Out:
# Ingrese un número: -415
# -415 es impar

# %% [markdown]
# **7.** Averiguar si dados dos números leídos del teclado, uno es divisor de otro.

# %%
num1 = int(input("Ingrese el primer número: "))
num2 = int(input("Ingrese el segundo número: "))

mayor = max(num1, num2)
menor = min(num1, num2)

if (mayor % menor == 0):
    print(f"{menor} es divisor de {mayor}")
else:
    print("Ninguno de los dos números es divisor del otro")
# Out:
# Ingrese el primer número: 54
# Ingrese el segundo número: 4
# Ninguno de los dos números es divisor del otro

# %% [markdown]
# **8.** Leer tres números y determinar si la suma de cualquier pareja de ellos es igual al otro número. Si se cumple esta condición escribir "Iguales", en caso contrario, escribir "Distintas".

# %%
num1 = int(input("Ingrese el primer número: "))
num2 = int(input("Ingrese el segundo número: "))
num3 = int(input("Ingrese el tercer número: "))

if (num1 + num2 == num3):
    print(f"La suma de {num1} con {num2} es igual a {num3}")
elif(num1 + num3 == num2):
        print(f"La suma de {num1} con {num3} es igual a {num2}")

elif(num2 + num3 == num1):
        print(f"La suma de {num2} con {num3} es igual a {num1}")

else:
        print(f"La suma de cualquier dos valores es distinta al tercer valor")
# Out:
# Ingrese el primer número: -5
# Ingrese el segundo número: 3
# Ingrese el tercer número: 8
# La suma de -5 con 8 es igual a 3

# %% [markdown]
# **9.** A un trabajador le pagan según sus horas y una tarifa de pago por horas. Si la cantidad de horas trabajadas es mayor a 40 horas. La tarifa se incrementa en un 50% para las horas extras. Calcular el salario del trabajador dadas las horas trabajadas y la tarifa.

# %%
tarifa_hora = float(input("Ingrese la tarifa por hora de trabajo: "))
horas = float(input("Ingrese el número de horas trabajadas: "))
porcentaje_extra = float(input("Ingrese el porcentaje extra para horas extra (ej. 50): "))

if horas <= 0:
    print("El trabajador no recibe pago")
else:
    if horas <= 40:
        salario_total = tarifa_hora * horas
        print(f"El trabajador recibe ${salario_total:.2f}")
    else:
        horas_extra = horas - 40
        tarifa_extra = tarifa_hora * (1 + porcentaje_extra / 100)

        salario_normal = tarifa_hora * 40
        salario_extra = tarifa_extra * horas_extra
        salario_total = salario_normal + salario_extra

        print(f"Se trabajaron {horas_extra} horas extra con tarifa de ${tarifa_extra:.2f}")
        print(f"El trabajador recibe ${salario_normal:.2f} + ${salario_extra:.2f} = ${salario_total:.2f}")
# Out:
# Ingrese la tarifa por hora de trabajo: 1000
# Ingrese el número de horas trabajadas: 41.5
# Ingrese el porcentaje extra para horas extra (ej. 50): 50
# Se trabajaron 1.5 horas extra con tarifa de $1500.00
# El trabajador recibe $40000.00 + $2250.00 = $42250.00

# %% [markdown]
# **10.** Dada la duración en minutos de una llamada calcular el costo, considerando: Hasta tres minutos el costo es \$ 50 por minuto. Por encima de tres minutos es \$50 menos \$ 10 por cada minuto adicional.

# %%
duracion = float(input("Duración de llamada: "))
costo_base = 50

if duracion <= 0:
    print("La llamada no tiene costo")
elif duracion <= 3:
    costo_total = duracion * costo_base
    print(f"La llamada tiene un costo de ${costo_total:.2f}")
else:
    minutos_adicionales = duracion - 3
    costo_total = (3 * costo_base) + (minutos_adicionales * (costo_base - 10))
    print(f"La llamada tiene un costo de ${costo_total:.2f}")
# Out:
# Duración de llamada: 5
# La llamada tiene un costo de $230.00

# %% [markdown]
# **11.** Diseñar un algoritmo que me permita ingresar la hora, minutos y segundos y que me calcule la hora en el siguiente segundo ("0<= H <=23", "0<= M <=59" "0<= S<=59").

# %%
H = int(input("Ingrese la hora: "))
M = int(input("Ingrese los minutos: "))
S = int(input("Ingrese los segundos: "))

if (0<= H <=23) and 0<= M <=59 and 0<= S <=59 :

    S = S+1

    if(S == 60):
        S = 0
        M = M+1

        if (M == 60):
            M = 0
            H = H + 1
            if (H == 24):
                H = 0
    print(f"La hora un segundo después es: {H} horas con {M} minutos y {S} segundos")
else:
    print("Los valores no son validos")
# Out:
# Ingrese la hora: 20
# Ingrese los minutos: 56
# Ingrese los segundos: 59
# La hora un segundo después es: 20 horas con 57 minutos y 0 segundos

# %% [markdown]
# **12.** Escribir un algoritmo que determine si un año es bisiesto. Un año es bisiesto si es múltiplo de 4 (por ejemplo 1984). Los años múltiplos de 100 no son bisiestos, salvo si ellos son también múltiplos de 400 (2000 es bisiesto, pero; 1800 no lo es).

# %%
anio = int(input("Ingrese un año: "))

if 1 <= anio <= 9999:
    if (anio % 4 == 0 and anio % 100 != 0) or (anio % 400 == 0):
        print(f"{anio} es bisiesto")
    else:
        print(f"{anio} no es bisiesto")
else:
    print("Los años permitidos van desde el año 1 hasta el año 9999")
# Out:
# Ingrese un año: 1800
# 1800 no es bisiesto

# %% [markdown]
# **13.**  "ALMACENES BARATO BARATO" se encuentra de aniversario y ha programado una serie de ofertas con la finalidad de brindar facilidades a sus clientes y a la vez de incrementar sus ventas. Estas ofertas se basan específicamente en un porcentaje de descuento sobre el total de compra el cual varía de acuerdo al monto:
# Por un monto mayor o igual a \$500000 se hará un descuento del 30%.
# Por un monto menor de \$500000 pero mayor o igual a \$200000 se hará un descuento del 20%

# %%
compra = float(input("Ingrese el monto de la compra: "))

if compra >= 0:
    if compra >= 500000:
        descuento = compra * 0.3
        print(f"Tiene un descuento de {descuento:.2f}")
        print(f"La compra queda con un valor de {(compra - descuento):.2f}")
    elif compra >= 200000:
        descuento = compra * 0.2
        print(f"Tiene un descuento de {descuento:.2f}")
        print(f"La compra queda con un valor de {(compra - descuento):.2f}")
    else:
        print("La compra no tiene descuento")
else:
    print("El valor no es válido")
# Out:
# Ingrese el monto de la compra: 199999
# La compra no tiene descuento

# %% [markdown]
# **14** Katthy organiza una fiesta en la cual una computadora controla el ingreso mediante 5 claves. Si se ingresa al menos una clave incorrecta esta imprimirá "TE EQUIVOCASTE DE FIESTA" y no permitirá el ingreso. Si las 5 claves son correctas imprimirá "BIENVENIDO A LA FIESTA" Las Claves son:
# 1: "TIENES"
# 2: "QUE SER"
# 3: "INVITADO"
# 4: "PARA"
# 5: "INGRESAR"

# %%
claves_correctas = ["TIENES", "QUE SER", "INVITADO", "PARA", "INGRESAR"]
clave_ingresada = []
for i in range(5):
    entrada = input(f"Ingrese la clave {i+1}: ").strip().upper()
    clave_ingresada.append(entrada)

if clave_ingresada == claves_correctas:
    print("BIENVENIDO A LA FIESTA")
else:
    print("TE EQUIVOCASTE DE FIESTA")
# Out:
# Ingrese la clave 1: tIENES
# Ingrese la clave 2: Que seR
# Ingrese la clave 3: invitado
# Ingrese la clave 4: PaRa
# Ingrese la clave 5: ingresAr
# BIENVENIDO A LA FIESTA
